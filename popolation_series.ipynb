# %%
import pandas as pd

# %%
df = pd.read_excel('base-cc-serie-historique-2015.xls',
                   sheet_name=0, skiprows=5)

# %%
# ! ls | grep xls

# %% [markdown]
# ## What you get for your money
#
# These are the variables/columns in the excel file
#
# https://www.insee.fr/fr/information/1303422

# %%
dfx
# Out:
#          VAR_ID                                            VAR_LIB  \
# 0        CODGEO                                  Code géographique
# 1           REG                                             Région
# 2           DEP                                        Département
# 3        LIBGEO                               Libellé géographique
# 4       P15_POP                         Population en 2015 (princ)
# 5       P10_POP                         Population en 2010 (princ)
# 6       D99_POP                          Population en 1999 (dnbt)
# 7       D90_POP                          Population en 1990 (dnbt)
# 8       D82_POP                          Population en 1982 (dnbt)
# 9       D75_POP                          Population en 1975 (dnbt)
# 10      D68_POP                          Population en 1968 (dnbt)
# 11       SUPERF                               Superficie (en km²)
# 12     NAIS1015                      Naissances entre 2010 et 2015
# ...

# %%
dfx = pd.read_excel('base-cc-serie-historique-2015.xls',
                   sheet_name=2, skiprows=5)

# %%
df_villages = df[df['P15_POP'] < 5000]

# %%
tt = (df_villages['P15_POP']/ df_villages['D90_POP']) - 1

# %%
df_v = df_villages[['LIBGEO','CODGEO']]

# %%
df_v.loc[:,'POP_INC'] = pd.Series(tt, index=df_v.index)
# Out:
# /home/gregmcshane/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/gregmcshane/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
df_v[df_v['POP_INC'] > .5]
# Out:
#                          LIBGEO CODGEO   POP_INC
# 1         L'Abergement-de-Varey  01002  0.515723
# 8                     Anglefort  01010  0.649199
# 16                        Armix  01019  0.714286
# 17              Ars-sur-Formans  01021  0.609871
# 20                     Attignat  01024  0.873874
# 21                Bâgé-la-Ville  01025  0.621746
# 23                        Balan  01027  0.796763
# 24                      Baneins  01028  0.583554
# 25                     Beaupont  01029  0.616114
# 32            Belmont-Luthézieu  01036  0.857143
# 36                     Béréziat  01040  0.571429
# 40                      Billiat  01044  0.517677
# 41                      Birieux  01045  1.296000
# 43                        Blyes  01047  0.869159
# 45                      Boissey  01050  0.606796
# 49       Bourg-Saint-Christophe  01054  0.793296
# 50          Boyeux-Saint-Jérôme  01056  0.502075
# 52              Brégnier-Cordon  01058  0.675147
# ...
